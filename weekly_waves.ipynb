# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('chris_fantasy.csv')
df2 = pd.read_csv('arian_fantasy.csv')
df3 = pd.read_csv('james_fantasy.csv')
df4 = pd.read_csv('harish_fantasy.csv')
df5 = pd.read_csv('daniel_fantasy.csv')
df6 = pd.read_csv('joey_fantasy.csv')
df7 = pd.read_csv('fantasy_weekly.csv')

# %%
df.drop('QD', axis = 1, inplace = True)

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['FGM'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['FGM'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['FGM'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['FGM'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['FGM'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['FGM'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('FGM')
# plt.yticks(np.arange(df['FGM'].min() - 10, df['FG%'].max() + 10, step= 100))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['FGM'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['FGM'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['FG%'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['FG%'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['FG%'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['FG%'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['FG%'], marker = 'o', label = 'Koshy', alpha = 0.5)
ax.plot(df6['Week'], df6['FG%'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('FG%')
# plt.yticks(np.arange(df['FG%'].min() - .005, df['FG%'].max() + 0.005, step=.01))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['FG%'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['FG%'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['FTM'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['FTM'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['FTM'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['FTM'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['FTM'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['FTM'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.legend(bbox_to_anchor=(1.25, 1), loc='best')
plt.title('FTM')
#plt.yticks(np.arange(df['FTM'].min() - .10, df['FT%'].max() + 10, step=100))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['FTM'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['FTM'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['FT%'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['FT%'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['FT%'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['FT%'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['FT%'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['FT%'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.legend(bbox_to_anchor=(1.25, 1), loc='best')
plt.title('FT%')
# plt.yticks(np.arange(df['FT%'].min() - .005, df['FT%'].max() + 0.005, step=.01))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['FT%'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['FT%'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['3PM'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['3PM'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['3PM'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['3PM'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['3PM'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['3PM'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.legend(bbox_to_anchor=(1.25, 1), loc='best')
plt.title('3PM')
# plt.yticks(np.arange(df['3PM'].min() - 10, df['3PM'].max() + 10, step=10))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['3PM'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['3PM'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['3P%'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['3P%'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['3P%'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['3P%'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['3P%'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['3P%'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.legend(bbox_to_anchor=(1.25, 1), loc='best')
plt.title('3P%')
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['3P%'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['3P%'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['OREB'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['OREB'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['OREB'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['OREB'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['OREB'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['OREB'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('OREB')
# plt.legend(bbox_to_anchor=(1.25, 1), loc='best')
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['OREB'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['OREB'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['DREB'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['DREB'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['DREB'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['DREB'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['DREB'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['DREB'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('DREB')
# plt.yticks(np.arange(df['DREB'].min() - 10, df['DREB'].max() + 10, step=10))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['DREB'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['DREB'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['AST'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['AST'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['AST'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['AST'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['AST'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['AST'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('AST')
# plt.yticks(np.arange(df['AST'].min() - 10, df['AST'].max() + 10, step=10))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['AST'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['AST'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['A/TO'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['A/TO'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['A/TO'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['A/TO'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['A/TO'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['A/TO'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('A/TO')
# plt.yticks(np.arange(df['A/TO'].min() - .005, df['A/TO'].max() + .005, step=.1))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['A/TO'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['A/TO'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['STL'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['STL'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['STL'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['STL'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['STL'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['STL'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('STL')
# plt.yticks(np.arange(df['STL'].min() - 5, df['STL'].max() + 5, step=5))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['STL'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['STL'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['BLK'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['BLK'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['BLK'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['BLK'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['BLK'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['BLK'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('BLK')
# plt.yticks(np.arange(df['BLK'].min() - 5, df['BLK'].max() + 5, step=5))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['BLK'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['BLK'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['TO'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['TO'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['TO'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['TO'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['TO'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['TO'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('TO')
# plt.yticks(np.arange(df['TO'].min() - 10, df['BLK'].max() + 10, step=10))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['TO'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['TO'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['DD'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['DD'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['DD'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['DD'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['DD'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['DD'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.title('DD')
# plt.yticks(np.arange(df['DD'].min() - 3, df['DD'].max() + 3, step=3))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['DD'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange')
std = df7['DD'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green')
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red')
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['TD'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['TD'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['TD'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['TD'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['TD'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['TD'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.legend(bbox_to_anchor=(1.25, 1), loc='best')
plt.title('TD')
# plt.yticks(np.arange(df['TD'].min(), df['TD'].max() + 1, step=1))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['TD'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['TD'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111)
ax.plot(df['Week'], df['PTS'], marker = 'o', label = 'Chris', alpha = 0.5)
ax.plot(df2['Week'], df2['PTS'], marker = 'o', label = 'Arian', alpha = 0.5)
ax.plot(df3['Week'], df3['PTS'], marker = 'o', label = 'James', alpha = 0.5)
ax.plot(df4['Week'], df4['PTS'], marker = 'o', label = 'Harish', alpha = 0.5)
ax.plot(df5['Week'], df5['PTS'], marker = 'o', label = 'Daniel', alpha = 0.5)
ax.plot(df6['Week'], df6['PTS'], marker = 'o', label = 'Joey', alpha = 0.5)
plt.legend(bbox_to_anchor=(1.25, 1), loc='best')
plt.title('PTS')
# plt.yticks(np.arange(df['PTS'].min() - 20, df['PTS'].max() + 20, step=20))
plt.xticks(np.arange(df['Week'].min(), df['Week'].max() + 1, 1))
pinny_middle = df7['PTS'].mean()
plt.axhline(y=pinny_middle, label='Average stilllll', linestyle='--', color='orange', alpha = 0.5)
std = df7['PTS'].std()
pinny_top = pinny_middle + std
plt.axhline(y=pinny_top, label='Exceptional!', linestyle='--', color='green', alpha = 0.5)
pinny_bottom = pinny_middle - std
plt.axhline(y=pinny_bottom, label='Terrible!', linestyle='--', color='red', alpha = 0.5)
plt.legend(bbox_to_anchor=(1, 1), loc='best')
